# %%
## NAME: @CXAEM
## ASSIGNMENT:   A1: Text Adventure Game
##########################################

"""
    DocString:
    
    A) Introduction:
    
    This interactive fiction game is based on the classic Nintendo 64 title 
    "The Legend of Zelda: Ocarina of Time," released in 1998.
    
    In this game, players must solve four riddles that will test their wisdom,
    courage, and strength.
    
    By solving the riddles, players will collect the "Triforce of Wisdom", 
    "Triforce of Courage" and "Triforce of Power." These three pieces are 
    crucial in defeating the evil sorcerer Ganondorf, the game's final boss.
    
    The game begins at the Temple of Time, where players start their journey.
    Round 1 is the Riddle of Wisdom, where players must answer riddles to move
    forward. Round 2 is the Trials of Courage, where players must prove their 
    bravery. Round 3 is the Challenge of Power, where players must demonstrate
    their strength.
    
    Once all three rounds are completed, the player will be transported to 
    Ganon's Castle, where they will face the final boss.
    
    This game requires players to have previously played "The Legend of Zelda:
    Ocarina of Time" as the events in this game build upon the original game's
    story. Get ready to put your wit and bravery to the test as you embark on 
    this thrilling adventure.
    
    Enjoy!
    
    B) Known Bugs and/or Errors:
    
    v.01 : Main structure completed.
    v.02 : Enhanced visual starting page fixed.
    v.03 : def win scenaario fixed.
    v.04 : def fail scenario fixed.
    v.05 : def start Fixed.
    v.06 : def ganondorf Fixed.
    v.07 : def temple_light Fixed.
    v.08 : Enhancing UX.
    v.09 : str ganon variable error Fixed
    v.10 : NONE
    
"""

from sys import exit
import random

# Begining of the game

def start():
    print(f"""
          
------------------------------------------------------------------------------
          
            ____________
           | ________  /     T H E  L E G E N D  O F                    
           |/       / /_________ _____    _______     ____              
                   /// \   ____ |\   /    \   __ \    \  /              
                  ///   | |    \| | |      | |  \ \    /_ \             
                 ///    | |__/|   | |      | |   | |  //_\ \            
                /*/     |  __ |   | |      | |   | | /_____ \           
               ///      | |  \|   | |      | |   | |//     \ \          
              ///       | |____/| | |___/| | |__/ ///       \ \         
             ///       /________|/_______|/______//_\       /__\        
            / /_______/|                   
           /___________|   O C A R I N A  O F  T I M E

                The Last Challenge before the Final Boss!!!
                         
------------------------------------------------------------------------------
    
As Link, the Hero of Hyrule, you have been summoned by the Sages to retrieve 
the Triforce, a formidable artifact that has the power to grant the wish of 
its holder. 

Your mission is to save the kingdom from darkness and rescue Princess Zelda 
from the clutches of the evil Gerudo king, Ganondorf. 

But before you can wield the Triforce, you must demonstrate your worthiness by
solving three challenging puzzles in the Temple of Time.
    
------------------------------------------------------------------------------    
    \n""")
    input("<Press enter to continue>\n")
    starting_path()

    
def starting_path():
    print(f"""
    
Link traveled to the Temple of Time, where the sages were eagerly waiting for 
him.Engraved on the frame of the main entrance was a message.
    
You read the following:

\t___|\_________________________    
\t___|/_________________________
\t__/|____⬅️_______⬅️__________
\t__\/\_______⬇️_______⬇️______
\t___|/_____🅰️_______🅰️________
\t   |
 
    
As Link, you are presented with three options:
    
    
    (1) Play the Song to Time.
    
    (2) Rest here an decide later.
    
    (3) Run away!

------------------------------------------------------------------------------

    """)
    
    # Anwser to go to the Temple of Light
    choice = input(">")
    if "1" in choice or "play" in choice or "time" in choice:
        print("""
------------------------------------------------------------------------------
       
Option (1): Play the Song to Time. You are teleported inside Temple of Light!
        
------------------------------------------------------------------------------
        """)
    
        input("<Press enter to continue>\n")
        temple_light()
    
    # Anwser will repeat the question
    elif "2" in choice or "rest" in choice or "later" in choice:
        print("""
------------------------------------------------------------------------------

Option (2): Now that you're rested, what would you like to do?

------------------------------------------------------------------------------
        """)
        input("<Press enter to continue>\n")
        starting_path()
    
    # Anwser will fail the quest, ending the game
    elif "3" in choice or "run" in choice:
        print("""
------------------------------------------------------------------------------

Option (3): Run away!

------------------------------------------------------------------------------
        """)
        
        fail()
        
    # Anything else will repeat the question
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        starting_path()

def temple_light():
    print("""

------------------------------------------------------------------------------

As you stand ready to begin the ultimate trial set by the Sages, Rauru, the 
revered Hylian priest who resides in the Temple of Time, suddenly appears 
before you. With a resounding voice, he declares:

Rauru: "Link, the hero of Hyrule, hear me now.
        
        In order to obtain the Triforce, the artifact of great power that 
        could grant its possessor's wish and save the land from the grasp of 
        evil, you must first prove your worth by solving these three riddles. 
        
        Are you ready to test your skills?".

------------------------------------------------------------------------------
        """)
    input("<Press enter to continue>\n")
    
    
    # Define list of dictionaries for riddles and corresponding anwsers
    question_list = [{"name": "The Riddle of Wisdom:",
                  "riddle": """
I am the key to unlocking secrets untold,
I guide you to the answers you seek, so bold.
With me, you'll solve puzzles, new and old,
And bring balance to the kingdom, story untold.
                  
What am I?
                  """,
                  "answer": "Wisdom",
                  "item_awarded": "Triforce of Wisdom"},
                 {"name":"The Riddle of Courage:",
                  "riddle":"""
I guide you through dark dungeons and into the light,
I give you strength to face your fright.
With me, you'll conquer evil's might,
And become the hero, shining bright.
                  
What am I?
                  """,
                  "answer": "Courage",
                  "item_awarded": "Triforce of Courage"},
                 {"name": "Riddle of Power",
                  "riddle":"""
I am the force that smashes through rock and stone,
I give you might, to face foes all alone.
With me, you'll conquer dungeons on your own,
And bring victory, with power all your own.
                  
What am I?
                  """,
                  "answer": "Power",
                  "item_awarded": "Triforce of Power"}]
    # Define riddles questions
    question = 0

    while question < 3:

        print(question_list[question]["name"],"\n\n", question_list[question]["riddle"])
        print("""(1) Wisdom\n(2) Courage\n(3) Power\n
------------------------------------------------------------------------------

                """)
        answer = input("<Press enter for your answer>\n")

        if answer == question_list[question]["answer"] or answer == str(question+1):

            print(f"""\nCorrect! Link can now use the {question_list[question]["item_awarded"]}!
            
------------------------------------------------------------------------------    
    \n""")
            question += 1

        else:
            print("Incorrect! Try again")
    # Message before going to next stage
    if question == 3:
        print("""
        
------------------------------------------------------------------------------
Link has acquired the Triforce, the powerful artifact granted to him by the 
Sages. With this powerful tool in hand, he is now ready to face the final evil
boss, Ganondorf. 
    
It is a decisive moment in his quest, and the outcome of the battle will 
determine the fate of the land. With the Triforce on his side, Link has the
strength, the courage and the wisdom to take on the evil Ganon and restore 
peace to the land once and for all. 
        
The time has come for the hero to confront his destiny and emerge victorious 
in the final showdown. 

------------------------------------------------------------------------------

<Press enter to continue>
            
            """)
    ganondorf()
    # Message explaing options
def ganondorf():
    print("""
    
Link stood before the final boss, the evil sorcerer Ganon. The fate of the
kingdom rested on the hero's shoulders, and he knew that the time had come
to face his greatest challenge. With determination in his eyes, Link 
prepared himself for battle.
    
    (1) Attack with the Master Sword.

    (2) Use the Triforce.

    (3) Run away. 
    
    """)
    ganon = input("> ")
    
    # Anwser will repeat the question
    if '1' in ganon or 'attack' in ganon or 'sword' in ganon:
        print("""

------------------------------------------------------------------------------        

Link drew his trusty blade, the Master Sword, from its sheath. With its power 
in hand, he charged at Ganon, ready to strike the final blow. 
        
In the heat of battle, Link swung his Master Sword with all his might, but 
Ganon was ready. The evil sorcerer effortlessly blocked the attack and sent 
Link hurtling into oblivion. The hero disappeared into the void, lost to the 
world. 
        
However, the Sages were watching and saw what had happened.
        
They immediately sprang into action, using their powerful magic to send Link 
back in time. They gave the hero a second chance to complete his quest and 
defeat Ganon once and for all.
        
Link reappeared in the past, ready for another chance to prove himself as the 
Hero of Time. With newfound determination, he set out on his journey once more,
determined to vanquish the evil sorcerer and restore peace to the land. The 
Sages had given him a second chance, and Link was determined to make the most 
of it.

------------------------------------------------------------------------------

            """)
        
        input("<Press enter to continue>\n")
        
        ganondorf()
        
    # Anwser will complete the quest, ending the game
    elif '2' in ganon or 'triforce' in ganon:
        print("""
        
Link remembered the Triforce, the powerful artifact granted to him by the 
Sages. He called forth its power and harnessed its strength, ready to use it 
against Ganondorf!

------------------------------------------------------------------------------

        """)
        win()
    
    # Anwser will fail the quest, ending the game
    elif '3' in ganon or 'run' in ganon:
        fail()  
    
    # Anything else will repeat the question
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")

# Define win scenario
def win():
    print("""
Link's hard-fought battle against Ganon has come to an end with a resounding 
victory. With the power of the Triforce and his own bravery, Link defeated the
evil sorcerer and brought peace back to the land. 
    
The people rejoiced as they celebrated the hero's triumph over evil, and the 
kingdom was restored to its former glory. Link, who had been on a perilous 
journey filled with challenges and obstacles, finally succeeded in his quest 
to save the land and its people. 

Link's victory over Ganondorf marked the end of a long and difficult journey, 
and the beginning of a new era of peace and prosperity. The hero's legacy will 
live on forever in the memories of the people he saved and the land he 
protected, as the Hero of Hyrule and the Hero of Time!
      
------------------------------------------------------------------------------
 
    <Game Over>
          
------------------------------------------------------------------------------
     
    """)
    exit(0)

# Define fail scenario
def fail():
    print(f"""
Rauru, the Sage of Light, stood before Link with a stern expression. 
    
Rauru: "Link, you have failed in your quest to defeat Ganon and save the 
        land. As the Hero of Hyrule, it was your responsibility to bring peace
        to the kingdom, but you have fallen short." 
    
Rauru paused, his gaze piercing into the hero. 
    
Rauru: "You are not worthy of being the title of Hero of Hyrule nor of Hero of
        Time. Your journey has come to an end, and the game is over." 

Link hung his head in defeat, realizing that he had failed to live up to the 
expectations placed upon him. Despite his best efforts, he had not been able 
to defeat the evil Ganon and save the kingdom.
    
The once-great hero was now left to face the consequences of his failure.
      
------------------------------------------------------------------------------
 
    <Game Over>
          
------------------------------------------------------------------------------
     
    """)
    exit(0)

# Starting the game!
start()
# Out:
#
# ------------------------------------------------------------------------------
#
#             ____________
#            | ________  /     T H E  L E G E N D  O F
#            |/       / /_________ _____    _______     ____
#                    /// \   ____ |\   /    \   __ \    \  /
#                   ///   | |    \| | |      | |  \ \    /_ \
#                  ///    | |__/|   | |      | |   | |  //_\ \
#                 /*/     |  __ |   | |      | |   | | /_____ \
#                ///      | |  \|   | |      | |   | |//     \ \
#               ///       | |____/| | |___/| | |__/ ///       \ \
#              ///       /________|/_______|/______//_\       /__\
#             / /_______/|
#            /___________|   O C A R I N A  O F  T I M E
#
#                 The Last Challenge before the Final Boss!!!
#
# ------------------------------------------------------------------------------
#
# As Link, the Hero of Hyrule, you have been summoned by the Sages to retrieve
# ...
